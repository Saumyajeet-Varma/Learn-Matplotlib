# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cell 01

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, 'o:r')
plt.show()

# %% [markdown]
# ## Cell 02

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, 'p--m')
plt.show()

# %% [markdown]
# ## Cell 03

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, 's-.g')
plt.show()
