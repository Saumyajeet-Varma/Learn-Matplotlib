# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cell 01

# %%
Xpoints = np.array([0, 5])
Ypoints = np.array([0, 250])

plt.plot(Xpoints,Ypoints)
plt.show()

# %% [markdown]
# ## Cell 02

# %%
Xpoints = np.array([0, 5])
Ypoints = np.array([0, 250])

plt.plot(Xpoints,Ypoints, 'o')
plt.show()

# %% [markdown]
# ## Cell 03

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints)
plt.show()

# %% [markdown]
# ## Cell 04

# %%
Ypoints = np.array([0, 2, 1, 6, 4])

plt.plot(Ypoints)
plt.show()
