# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cell 01

# %%
x1 = np.array([1, 4, 5, 7])
y1 = np.array([3, 8, 1, 10])

x2 = np.array([1, 4, 5, 8])
y2 = np.array([6, 2, 7, 9])

plt.plot(x1, y1)
plt.plot(x2, y2)

plt.show()

# %% [markdown]
# ## Cell 02

# %%
x1 = np.array([1, 4, 5, 7])
y1 = np.array([3, 8, 1, 10])

x2 = np.array([1, 4, 5, 8])
y2 = np.array([6, 2, 7, 9])

plt.plot(x1, y1, x2, y2)

plt.show()
