# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cell 01

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, ls = ':')
plt.show()

# %% [markdown]
# ## Cell 02

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, ls = '--')
plt.show()

# %% [markdown]
# ## Cell 03

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, ls = '-.')
plt.show()

# %% [markdown]
# ## Cell 04

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, color = 'r')
plt.show()

# %% [markdown]
# ## Cell 05

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, color = 'g')
plt.show()

# %% [markdown]
# ## Cell 06

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, ls = '--', color = 'y')
plt.show()

# %% [markdown]
# ## Cell 07

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, linewidth = '10')
plt.show()
