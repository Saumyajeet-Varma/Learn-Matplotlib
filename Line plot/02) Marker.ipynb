# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cell 01

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, marker = 'o')
plt.show()

# %% [markdown]
# ## Cell 02

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, marker = '*')
plt.show()

# %% [markdown]
# ## Cell 03

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, marker = 's')
plt.show()

# %% [markdown]
# ## Cell 04

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, marker = 'o', ms = 15)
plt.show()

# %% [markdown]
# ## Cell 05

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, marker = 'o', ms = 15, mec = 'r')
plt.show()

# %% [markdown]
# ## Cell 06

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, marker = 's', ms = 15, mec = 'r', mfc = 'g')
plt.show()

# %% [markdown]
# ## Cell 07

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, marker = 'o', ms = 15, mec = 'y', mfc = 'y')
plt.show()

# %% [markdown]
# ## Cell 08

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, 'p--m')
plt.show()

# %% [markdown]
# ## Cell 09

# %%
Xpoints = np.array([0, 1, 3, 5])
Ypoints = np.array([0, 2, 1, 6])

plt.plot(Xpoints,Ypoints, 's-.g')
plt.show()
